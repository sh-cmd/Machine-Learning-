# %%
import os 
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics
os.chdir(r'C:\Users\shubham\Desktop\case_study_python\8 Supervised Learning 2')

# %%
dataset = pd.read_csv('College.csv')

# %%
dataset
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0       Yes   1660    1232     721         23         52         2885
# 1       Yes   2186    1924     512         16         29         2683
# 2       Yes   1428    1097     336         22         50         1036
# 3       Yes    417     349     137         60         89          510
# 4       Yes    193     146      55         16         44          249
# ..      ...    ...     ...     ...        ...        ...          ...
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# 774     Yes   2097    1915     695         34         61         2793
# 775     Yes  10705    2453    1317         95         99         5217
# 776     Yes   2989    1855     691         28         63         2988
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
x = dataset.loc[:,dataset.columns != 'Private']
y = dataset.loc[:,dataset.columns == 'Private']

# %%
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2 , random_state = 0)

# %%
dataset.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
from sklearn.svm import SVC
svm_cfr = SVC(kernel = 'linear')
svm_cfr.fit(x_train,y_train)
# Out:
# C:\Users\shubham\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# SVC(kernel='linear')

# %%
y_pred = svm_cfr.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
# Out:
# [[ 37   4]
#  [  8 107]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.82      0.90      0.86        41
#          Yes       0.96      0.93      0.95       115
#
#     accuracy                           0.92       156
#    macro avg       0.89      0.92      0.90       156
# weighted avg       0.93      0.92      0.92       156

# %%
svm_cfr.score(x_test, y_test)
# Out:
# 0.9230769230769231

# %%
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.9230769230769231

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2 , random_state = 0)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.svm import SVC
svm_cfr = SVC(kernel = 'linear')
svm_cfr.fit(x_train,y_train)
y_pred = svm_cfr.predict(x_test)
# Out:
# C:\Users\shubham\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
# Out:
# [[ 37   4]
#  [  6 109]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.86      0.90      0.88        41
#          Yes       0.96      0.95      0.96       115
#
#     accuracy                           0.94       156
#    macro avg       0.91      0.93      0.92       156
# weighted avg       0.94      0.94      0.94       156

# %%
svm_cfr.score(x_test, y_test)
# Out:
# 0.9358974358974359

# %%
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.9358974358974359

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [0.1,1, 10, 100], 'gamma': [1,0.1,0.01,0.001],'kernel': ['rbf', 'poly', 'sigmoid']}
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=2)
grid.fit(x_train,y_train)
print(grid.best_estimator_)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=0.1, gamma=1, kernel=rbf, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=0.1, gamma=1, kernel=rbf, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=0.1, gamma=1, kernel=rbf, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=0.1, gamma=1, kernel=rbf, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=0.1, gamma=1, kernel=rbf, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=poly .....................................
# [CV] ...................... C=0.1, gamma=1, kernel=poly, total=   0.0s
# ...

# %%
grid_predictions = grid.predict(x_test)
print(confusion_matrix(y_test,grid_predictions))
print(classification_report(y_test,grid_predictions))
# Out:
# [[ 36   5]
#  [  5 110]]
#               precision    recall  f1-score   support
#
#           No       0.88      0.88      0.88        41
#          Yes       0.96      0.96      0.96       115
#
#     accuracy                           0.94       156
#    macro avg       0.92      0.92      0.92       156
# weighted avg       0.94      0.94      0.94       156

# %%
grid.score(x_test,y_test)
# Out:
# 0.9358974358974359

# %%
metrics.accuracy_score(y_test, grid_predictions)
# Out:
# 0.9358974358974359

# %%
from sklearn.svm import SVC
svm_cfr = SVC(kernel = 'sigmoid')
svm_cfr.fit(x_train,y_train)
y_pred = svm_cfr.predict(x_test)
# Out:
# C:\Users\shubham\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
# Out:
# [[ 38   3]
#  [  5 110]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.88      0.93      0.90        41
#          Yes       0.97      0.96      0.96       115
#
#     accuracy                           0.95       156
#    macro avg       0.93      0.94      0.93       156
# weighted avg       0.95      0.95      0.95       156

# %%
svm_cfr.score(x_test, y_test)
# Out:
# 0.9487179487179487
